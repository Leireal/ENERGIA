# %% [markdown]
# # ENERGÍA EN EL MUNDO
# ### Leire Alonso

# %% [markdown]
# <img src="./torre.jpg" alt="Texto alternativo" width="500" height="500"/>

# %% [markdown]
# ## 🌍 Introducción
#
# Actualmente, los países enfrentan una presión creciente por reducir sus emisiones de gases de efecto invernadero. Sin embargo, mientras algunos países han avanzado en la transición hacia energías limpias, otros continúan generando grandes cantidades de electricidad a partir de fuentes fósiles. Para compensar sus altos niveles de emisiones, muchos recurren a la compra de créditos de carbono, una herramienta del mercado climático que les permite financiar reducciones de emisiones en otros lugares del mundo.
#
# Este proyecto analiza un conjunto de datos energéticos, medioambientales y económicos a nivel mundial, con el objetivo de identificar qué países tienen altos niveles de generación energética y emisiones de CO₂, y cómo se relacionan con prácticas como la compra de créditos de carbono. Entre los indicadores analizados se encuentran:
#
# Acceso a electricidad y combustibles limpios
#
# Capacidad instalada de energía renovable
#
# Consumo de energía primaria y su intensidad
#
# Generación eléctrica por fuente (fósil, nuclear, renovable)
#
# Emisiones anuales de CO₂
#
# PIB per cápita y crecimiento económico
#
# El análisis busca destacar la paradoja de los países que, a pesar de contar con recursos y tecnología para reducir emisiones, optan por compensarlas económicamente en lugar de reducirlas directamente. Esto abre el debate sobre la eficacia y la equidad de los mercados de carbono, y plantea interrogantes clave sobre la justicia climática y el verdadero compromiso de las economías más contaminantes.
#
# A través de visualizaciones y comparaciones regionales, este proyecto pretende ofrecer una mirada crítica a los patrones de consumo energético, las responsabilidades históricas de emisiones, y el papel que juegan los créditos de carbono en las estrategias de sostenibilidad internacional.

# %% [markdown]
# ## Hipotesis

# %% [markdown]
# 1- Los países con mayor intensidad energética tienen un menor grado de eficiencia económica.
# Relación entre “Energy intensity level of primary energy” y “gdp_per_capita”.
#
# 2- Los países que generan más electricidad a partir de combustibles fósiles tienden a tener mayores emisiones de CO₂.
# Relación entre “Electricity from fossil fuels” y “Value_co2_emissions_kt_by_country”.
#
# 3- El acceso a combustibles limpios para cocinar está positivamente correlacionado con el nivel de desarrollo económico.
# Relación entre “Access to clean fuels for cooking” y “gdp_per_capita”.
#
# 4- Los países con mayor participación de energía renovable en el consumo final tienen una menor intensidad energética.
# Relación entre “Renewable energy share in the total final energy consumption” y “Energy intensity level of primary energy”.
#
# 5- Los paises más ricos son los que compran mas creditos de carbono. Y los mas porbres los que los venden.
#
# 6- Los paises ricos emiten más CO2 que lo compensan con la copra de creditos de carbono.
#
#
# Backup:
#
# 7- Los países con mayor acceso a la electricidad tienen un PIB per cápita más alto.
# Relación entre “Access to electricity” y “gdp_per_capita”.
#
# 8- El incremento en la generación de electricidad a partir de fuentes renovables reduce las emisiones de CO₂.
# Relación entre “Electricity from renewables” y “Value_co2_emissions_kt_by_country”.

# %% [markdown]
# ## Datos obtenidos

# %% [markdown]
# Se ha obtenido un archivo de nombre global_data.csv en Kaggle que contiene la siguiente información por pais y año:
#
# | Nº | Nombre original (en inglés)                                      | Traducción al español                                              |
# | -- | ---------------------------------------------------------------- | ------------------------------------------------------------------ |
# | 0  | Entity                                                           | País o entidad                                                     |
# | 1  | Year                                                             | Año                                                                |
# | 2  | Access to electricity (% of population)                          | Acceso a la electricidad (% de la población)                       |
# | 3  | Access to clean fuels for cooking                                | Acceso a combustibles limpios para cocinar                         |
# | 4  | Renewable-electricity-generating-capacity-per-capita             | Capacidad per cápita de generación de electricidad renovable       |
# | 5  | Financial flows to developing countries (US \$)                  | Flujos financieros a países en desarrollo (US \$)                  |
# | 6  | Renewable energy share in the total final energy consumption (%) | Porcentaje de energía renovable en el consumo final de energía (%) |
# | 7  | Electricity from fossil fuels (TWh)                              | Electricidad generada a partir de combustibles fósiles (TWh)       |
# | 8  | Electricity from nuclear (TWh)                                   | Electricidad generada por energía nuclear (TWh)                    |
# | 9  | Electricity from renewables (TWh)                                | Electricidad generada por fuentes renovables (TWh)                 |
# | 10 | Low-carbon electricity (% electricity)                           | Electricidad de bajas emisiones de carbono (% del total)           |
# | 11 | Primary energy consumption per capita (kWh/person)               | Consumo de energía primaria per cápita (kWh/persona)               |
# | 12 | Energy intensity level of primary energy (MJ/\$2017 PPP GDP)     | Intensidad energética de la energía primaria (MJ/\$ PIB PPA 2017)  |
# | 13 | Value\_co2\_emissions\_kt\_by\_country                           | Emisiones de CO₂ por país (miles de toneladas)                     |
# | 14 | Renewables (% equivalent primary energy)                         | Renovables (% equivalente de energía primaria)                     |
# | 15 | gdp\_growth                                                      | Crecimiento del PIB                                                |
# | 16 | gdp\_per\_capita                                                 | PIB per cápita                                                     |
# | 17 | Density\n(P/Km2)                                                 | Densidad de población (personas/km²)                               |
# | 18 | Land Area(Km2)                                                   | Superficie terrestre (km²)                                         |
# | 19 | Latitude                                                         | Latitud                                                            |
# | 20 | Longitude                                                        | Longitud                                                           |
#
# Los datos van del año 2000 al 2020 y se incluyen 176 paises.
#
# Se estudiará si es necesario completar con datos adicionales del mercado de creditos de carbono CAP AND TRADE.

# %% [markdown]
# ## Resumen de la tabla

# %%
import numpy as np
import pandas as pd

# %%
df_energy=pd.read_csv ("global_data.csv")

# %%
df_energy
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
df_energy.info()
# veo que la variable Density es un Object y solo tendria que ser numerica
# veo que hay bastantes NaN que limpiar
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                 3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   float64
#  5   Financial flows to developing countries (US $)                    1560 non-null   float64
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
# ...

# %%
#Numero de paises en la lista

len(df_energy['Entity'].unique())
# Out:
# 176

# %%
df_energy.describe (include="all")
# Out:
#              Entity         Year  Access to electricity (% of population)  \
# count          3649  3649.000000                              3639.000000
# unique          176          NaN                                      NaN
# top     Afghanistan          NaN                                      NaN
# freq             21          NaN                                      NaN
# mean            NaN  2010.038367                                78.933702
# std             NaN     6.054228                                30.275541
# min             NaN  2000.000000                                 1.252269
# 25%             NaN  2005.000000                                59.800890
# 50%             NaN  2010.000000                                98.361570
# 75%             NaN  2015.000000                               100.000000
# max             NaN  2020.000000                               100.000000
#
#         Access to clean fuels for cooking  \
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Buscando NaN

# %% [markdown]
# Tras realizar una revisión de los valores faltantes (NaN) en la tabla, se ha identificado la necesidad de eliminar algunos registros y omitir otros. No se ha llevado a cabo el proceso de limpieza de datos hasta el momento.

# %%
df_energy.isnull()
# Out:
#       Entity   Year  Access to electricity (% of population)  \
# 0      False  False                                    False
# 1      False  False                                    False
# 2      False  False                                    False
# 3      False  False                                    False
# 4      False  False                                    False
# ...      ...    ...                                      ...
# 3644   False  False                                    False
# 3645   False  False                                    False
# 3646   False  False                                    False
# 3647   False  False                                    False
# 3648   False  False                                    False
#
#       Access to clean fuels for cooking  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# ...

# %%
df_energy.isnull().sum()
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable-electricity-generating-capacity-per-capita                 931
# Financial flows to developing countries (US $)                      2089
# Renewable energy share in the total final energy consumption (%)     194
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# ...

# %% [markdown]
# ## Limpiar la tabla de caracteres que me dan problemas

# %%
#PRIMERA LIMPIEZA
#Copio la tabla
df_energy_2=df_energy

# %%
#PRIMERA LIMPIEZA
#cambio los nombres de las columnas porque algunos simbolos me dan problemas
df_energy_2.columns = [
    col.replace('$', 'dolar')
       .replace('%', 'perc')
    
    for col in df_energy_2.columns
]

# %%
#PRIMERA LIMPIEZA
df_energy_2.columns
# Out:
# Index(['Entity', 'Year', 'Access to electricity (perc of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US dolar)',
#        'Renewable energy share in the total final energy consumption (perc)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (perc electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (perc equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Density(P/Km2)', 'Land Area(Km2)', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
#PRIMERA LIMPIEZA
df_energy_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Entity                                                               3649 non-null   object
#  1   Year                                                                 3649 non-null   int64
#  2   Access to electricity (perc of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                    3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita                 2718 non-null   float64
#  5   Financial flows to developing countries (US dolar)                   1560 non-null   float64
# ...

# %%
#PRIMERA LIMPIEZA
df_energy_2["Density(P/Km2)"].unique()
# Out:
# array(['60', '105', '18', '26', '223', '17', '104', '590', '3', '109',
#        '123', '41', '2,239', '1,265', '668', '47', '383', '108', '1281',
#        '20', '64', '4', '25', '76', '463', '95', '56', '274', '8', '13',
#        '153', '46', '467', '100', '73', '106', '131', '136', '137', '43',
#        '96', '225', '71', '103', '313', '50', '35', '31', '67', '115',
#        '49', '119', nan, '9', '239', '57', '240', '81', '331', '167',
#        '53', '70', '414', '89', '107', '464', '151', '93', '400', '206',
#        '273', '347', '7', '94', '147', '34', '30', '667', '242', '48',
#        '203', '99', '1,802', '1,380', '5', '626', '66', '2', '83', '40',
#        '541', '508', '16', '55', '19', '226', '15', '287', '58', '368',
#        '124', '111', '248', '84', '525', '205', '301', '284', '87', '214',
#        '8,358', '114', '341', '219', '68', '152', '110', '393', '229',
#        '75', '118', '281', '36', '79', '38'], dtype=object)

# %%
#PRIMERA LIMPIEZA
# He encontrado que la columna Density(P/Km2) es de tipo object porque tiene algunos numeros con ,
df_energy_2["Density(P/Km2)"] = df_energy_2["Density(P/Km2)"].str.replace(",", "", regex=False)

# %%
#PRIMERA LIMPIEZA
df_energy_2["Density(P/Km2)"].unique()
# Out:
# array(['60', '105', '18', '26', '223', '17', '104', '590', '3', '109',
#        '123', '41', '2239', '1265', '668', '47', '383', '108', '1281',
#        '20', '64', '4', '25', '76', '463', '95', '56', '274', '8', '13',
#        '153', '46', '467', '100', '73', '106', '131', '136', '137', '43',
#        '96', '225', '71', '103', '313', '50', '35', '31', '67', '115',
#        '49', '119', nan, '9', '239', '57', '240', '81', '331', '167',
#        '53', '70', '414', '89', '107', '464', '151', '93', '400', '206',
#        '273', '347', '7', '94', '147', '34', '30', '667', '242', '48',
#        '203', '99', '1802', '1380', '5', '626', '66', '2', '83', '40',
#        '541', '508', '16', '55', '19', '226', '15', '287', '58', '368',
#        '124', '111', '248', '84', '525', '205', '301', '284', '87', '214',
#        '8358', '114', '341', '219', '68', '152', '110', '393', '229',
#        '75', '118', '281', '36', '79', '38'], dtype=object)

# %% [markdown]
# ### Solución para Density(P/Km2)

# %%
#PRIMERA LIMPIEZA
print(type("Density(P/Km2)"))
# Out:
# <class 'str'>

# %%
#PRIMERA LIMPIEZA
df_energy_2["Density(P/Km2)"] = df_energy_2["Density(P/Km2)"].astype(float)

# %%
#PRIMERA LIMPIEZA
print(type("Density(P/Km2)"))
#Me parece que como tiene un Nan no lo pasa a float
# Out:
# <class 'str'>

# %%
#PRIMERA LIMPIEZA
#Busco en que pais está el Nan
df_nan_density = df_energy_2[df_energy_2["Density(P/Km2)"].isna()]

df_nan_density[["Entity", "Year", "Density(P/Km2)"]]
# Out:
#              Entity  Year  Density(P/Km2)
# 1218  French Guiana  2000             NaN

# %%
#PRIMERA LIMPIEZA
# #Voy a ver que datos hay para French Guiana
df_energy_2[df_energy_2["Entity"] == "French Guiana"]
# Out:
#              Entity  Year  Access to electricity (perc of population)  \
# 1218  French Guiana  2000                                         NaN
#
#       Access to clean fuels for cooking  \
# 1218                                NaN
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 1218                                             702.29
#
#       Financial flows to developing countries (US dolar)  \
# 1218                                                NaN
#
#       Renewable energy share in the total final energy consumption (perc)  \
# 1218                                              23.84
#
#       Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 1218                                 0.43                             0.0
#
#       Electricity from renewables (TWh)  ...  \
# 1218                                0.0  ...
#
#       Primary energy consumption per capita (kWh/person)  \
# 1218                                          13692.394
# ...

# %%
#PRIMERA LIMPIEZA
# #Como está bastante vacio decido quitarme este pais, toda la linea
df_energy_2 = df_energy_2[df_energy_2["Entity"] != "French Guiana"]

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["Entity"] == "French Guiana"]
# Out:
# Empty DataFrame
# Columns: [Entity, Year, Access to electricity (perc of population), Access to clean fuels for cooking, Renewable-electricity-generating-capacity-per-capita, Financial flows to developing countries (US dolar), Renewable energy share in the total final energy consumption (perc), Electricity from fossil fuels (TWh), Electricity from nuclear (TWh), Electricity from renewables (TWh), Low-carbon electricity (perc electricity), Primary energy consumption per capita (kWh/person), Energy intensity level of primary energy (MJ/dolar2017 PPP GDP), Value_co2_emissions_kt_by_country, Renewables (perc equivalent primary energy), gdp_growth, gdp_per_capita, Density(P/Km2), Land Area(Km2), Latitude, Longitude]
# Index: []
#
# [0 rows x 21 columns]

# %%
#PRIMERA LIMPIEZA
df_energy_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3648 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Entity                                                               3648 non-null   object
#  1   Year                                                                 3648 non-null   int64
#  2   Access to electricity (perc of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                    3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita                 2717 non-null   float64
#  5   Financial flows to developing countries (US dolar)                   1560 non-null   float64
# ...

# %%
#Me quedo con un pais menos y se me reducen las columnas con Nan

# %%
#PRIMERA LIMPIEZA
df_energy_2.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                9
# Access to clean fuels for cooking                                       168
# Renewable-electricity-generating-capacity-per-capita                    931
# Financial flows to developing countries (US dolar)                     2088
# Renewable energy share in the total final energy consumption (perc)     194
# Electricity from fossil fuels (TWh)                                      21
# Electricity from nuclear (TWh)                                          126
# Electricity from renewables (TWh)                                        21
# Low-carbon electricity (perc electricity)                                42
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ### Durante el analisis he visto que el año 2020 tiene mucho NaN. quito este año

# %%
#PRIMERA LIMPIEZA
# quito el año 2020 de todos los paises de la primera tabla
df_energy_2 = df_energy_2[df_energy['Year'] != 2020]
# Out:
# C:\Users\leire\AppData\Local\Temp\ipykernel_13404\2761213598.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_energy_2 = df_energy_2[df_energy['Year'] != 2020]

# %%
#PRIMERA LIMPIEZA
df_energy_2.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                9
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    886
# Financial flows to developing countries (US dolar)                     1914
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                      20
# Electricity from nuclear (TWh)                                          120
# Electricity from renewables (TWh)                                        20
# Low-carbon electricity (perc electricity)                                40
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ### Solución para Access to electricity (perc of population)

# %%
#PRIMERA LIMPIEZA
# #Busco en que pais está el Nan
df_nan_density = df_energy_2[df_energy_2["Access to electricity (perc of population)"].isna()]

df_nan_density[["Entity", "Year", "Access to electricity (perc of population)"]]
# Out:
#              Entity  Year  Access to electricity (perc of population)
# 1408  Guinea-Bissau  2000                                         NaN
# 1409  Guinea-Bissau  2001                                         NaN
# 1891        Liberia  2000                                         NaN
# 1892        Liberia  2001                                         NaN
# 1893        Liberia  2002                                         NaN
# 1894        Liberia  2003                                         NaN
# 1895        Liberia  2004                                         NaN
# 1896        Liberia  2005                                         NaN
# 1897        Liberia  2006                                         NaN

# %% [markdown]
# En Guinea-Bissau, en el año 2000, el acceso a la electricidad era de un 0% según el Banco Mundial. Esto indica que, en ese año, prácticamente ninguna persona en Guinea-Bissau tenía acceso a la electricidad.
#
# En 2000, el acceso a la electricidad en Liberia era muy limitado. La infraestructura energética del país era principalmente la red eléctrica de Monrovia, con algunas líneas de distribución a los condados cercanos. Antes de la guerra civil, la infraestructura era limitada, y después de la guerra, se encontraba en un estado de deterioro.

# %%
#PRIMERA LIMPIEZA
#Estos datos los voy a susituir por 0
df_energy_2.loc[df_energy_2["Access to electricity (perc of population)"].isna(), "Access to electricity (perc of population)"] = 0

# %%
#PRIMERA LIMPIEZA
df_energy_2.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    886
# Financial flows to developing countries (US dolar)                     1914
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                      20
# Electricity from nuclear (TWh)                                          120
# Electricity from renewables (TWh)                                        20
# Low-carbon electricity (perc electricity)                                40
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ### Solución para Access to clean fuels for cooking

# %%
#PRIMERA LIMPIEZA
#Busco en que paises está el Nan

df_energy_2[df_energy_2["Access to clean fuels for cooking"].isna()]["Entity"].drop_duplicates()
# Out:
# 147              Aruba
# 399            Bermuda
# 504           Bulgaria
# 630     Cayman Islands
# 1849           Lebanon
# 1912             Libya
# 2346     New Caledonia
# 2682       Puerto Rico
# Name: Entity, dtype: object

# %% [markdown]
# ### Solución para Electricity from nuclear (TWh)

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["Electricity from nuclear (TWh)"].isna()]["Entity"].drop_duplicates()
# Out:
# 693            Chile
# 1555       Indonesia
# 1723      Kazakhstan
# 2017        Malaysia
# 2871    Saudi Arabia
# 3397          Tuvalu
# Name: Entity, dtype: object

# %% [markdown]
# He mirado en internet y en estos paises la producción de energia en centrales nucleares es cero.
# Pongo los NAN de esta columna a cero.

# %%
#PRIMERA LIMPIEZA
df_energy_2.loc[df_energy_2["Electricity from nuclear (TWh)"].isna(), "Electricity from nuclear (TWh)"] = 0

# %%
#PRIMERA LIMPIEZA
df_energy_2.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    886
# Financial flows to developing countries (US dolar)                     1914
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                      20
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                        20
# Low-carbon electricity (perc electricity)                                40
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ### Solución para Tuvalu: Electricity from renewables (TWh) y Electricity from fossil fuels (TWh)

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["Electricity from renewables (TWh)"].isna()]["Entity"].drop_duplicates()
# Out:
# 3397    Tuvalu
# Name: Entity, dtype: object

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["Electricity from renewables (TWh)"].isna()]["Entity"].drop_duplicates()
# Out:
# 3397    Tuvalu
# Name: Entity, dtype: object

# %% [markdown]
# Los NAN solo estan en Tuvalu.los pongo cero porque he enecontrado en internet que no tienen energias renovables.
# Tuvalu genera electricidad principalmente a través de plantas de energía que utilizan diésel importado,
# Como a este pais le faltan muchos datos, quito este pais.

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["Electricity from fossil fuels (TWh)"].isna()]["Entity"].drop_duplicates()
# Out:
# 3397    Tuvalu
# Name: Entity, dtype: object

# %%
#PRIMERA LIMPIEZA
df_energy_2 = df_energy_2[df_energy['Entity'] != 'Tuvalu']
# Out:
# C:\Users\leire\AppData\Local\Temp\ipykernel_13404\2798866024.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_energy_2 = df_energy_2[df_energy['Entity'] != 'Tuvalu']

# %%
#PRIMERA LIMPIEZA
df_energy_2.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    886
# Financial flows to developing countries (US dolar)                     1904
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ## Revisar datos

# %%
#ELIMINAR

# Contar NaNs por fila
df_energy['NaNs_por_fila'] = df_energy.isna().sum(axis=1)

# Filtrar filas con más de un NaN
df_muchos_nan = df_energy[df_energy['NaNs_por_fila'] > 5]

# Ordenar por cantidad de NaNs de mayor a menor
df_muchos_nan_ordenado = df_muchos_nan.sort_values(by='NaNs_por_fila', ascending=False)

# Mostrar Entity (país) y número de NaNs
print(df_muchos_nan_ordenado[['Entity', 'NaNs_por_fila']])
# Out:
#                                 Entity  NaNs_por_fila
# 1218                     French Guiana             12
# 3417                            Tuvalu              9
# 167                              Aruba              8
# 2366                     New Caledonia              8
# 419                            Bermuda              8
# 797                              Congo              7
# 1091                           Eritrea              7
# 2828  Saint Vincent and the Grenadines              7
# 2807                       Saint Lucia              7
# 2786             Saint Kitts and Nevis              7
# 1260                            Gambia              7
# 902                            Czechia              7
# 251                            Bahamas              7
# 3102                       South Sudan              7
# 3010                          Slovakia              7
# 3606                             Yemen              7
# ...

# %%
#ELIMINAR
# Contar NaNs por fila
df_energy_2['NaNs_por_fila'] = df_energy_2.isna().sum(axis=1)

# Filtrar filas con más de un NaN
df_muchos_nan = df_energy_2[df_energy_2['NaNs_por_fila'] > 5]

# Ordenar por cantidad de NaNs de mayor a menor
df_muchos_nan_ordenado = df_muchos_nan.sort_values(by='NaNs_por_fila', ascending=False)

# Mostrar Entity (país) y número de NaNs
print(df_muchos_nan_ordenado[['Entity', 'NaNs_por_fila']])
# Out:
#              Entity  NaNs_por_fila
# 166           Aruba              6
# 416         Bermuda              6
# 417         Bermuda              6
# 418         Bermuda              6
# 2364  New Caledonia              6
# 2365  New Caledonia              6
# 3602          Yemen              6

# %% [markdown]
# ### Financial flows to developing countries (US dolar) vemos cuales son los que estan a 0. Si son cero ver si tiene sentid0

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2['Financial flows to developing countries (US dolar)'] == 0]
# Out:
#                         Entity  Year  \
# 53                     Algeria  2011
# 382                      Benin  2004
# 657   Central African Republic  2006
# 665   Central African Republic  2014
# 667   Central African Republic  2016
# 683                       Chad  2011
# 791                      Congo  2014
# 1035               El Salvador  2006
# 1372                 Guatemala  2006
# 1458                     Haiti  2008
# 1781                  Kiribati  2016
# 1886                   Lesotho  2016
# 2432                   Nigeria  2002
# 2541                    Panama  2006
# 2570          Papua New Guinea  2014
# 2838                     Samoa  2009
# 2845                     Samoa  2016
# 2853     Sao Tome and Principe  2003
# 3180                  Suriname  2014
# 3288                      Togo  2017
# 3301                     Tonga  2009
# 3394              Turkmenistan  2018
# 3528                   Uruguay  2005
# 3529                   Uruguay  2006
# ...

# %% [markdown]
# Si, tiene sentido. Asi que los NaN los pongo a cero

# %%
#Si los pusiera a cero#PRIMERA LIMPIEZA
df_energy_2.loc[df_energy_2["Financial flows to developing countries (US dolar)"].isna(), "Financial flows to developing countries (US dolar)"] = 0

# %%
#PRIMERA LIMPIEZA
df_energy_2.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    886
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ### Vamos a ver donde estan los NaN en energy intensity y gpd per capita

# %%
#PRIMERA LIMPIEZA
#Busco en que paises está el Nan

df_energy_2[df_energy_2["Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)"].isna()]["Entity"].drop_duplicates()
# Out:
# 1087          Eritrea
# 2346    New Caledonia
# 3098      South Sudan
# 3602            Yemen
# Name: Entity, dtype: object

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["gdp_per_capita"].isna()]["Entity"].drop_duplicates()
# Out:
# 0                            Afghanistan
# 166                                Aruba
# 231                              Bahamas
# 630                       Cayman Islands
# 777                                Congo
# 882                              Czechia
# 1008                               Egypt
# 1083                             Eritrea
# 1240                              Gambia
# 1807                          Kyrgyzstan
# 2283                               Nauru
# 2766               Saint Kitts and Nevis
# 2787                         Saint Lucia
# 2808    Saint Vincent and the Grenadines
# 2850               Sao Tome and Principe
# 2990                            Slovakia
# 3053                             Somalia
# 3098                         South Sudan
# 3586                               Yemen
# Name: Entity, dtype: object

# %%
#PRIMERA LIMPIEZA
#grafico gdp_per_capita 
#Energy intensity level of primary energy (MJ/dolar2017 PPP GDP

# %%
#PRIMERA LIMPIEZA
# Busco en que pais está el Nan
df_gpd = df_energy_2[df_energy_2["gdp_per_capita"].isna()]

df_gpd[["Entity", "Year", "gdp_per_capita"]]
# Out:
#            Entity  Year  gdp_per_capita
# 0     Afghanistan  2000             NaN
# 1     Afghanistan  2001             NaN
# 166         Aruba  2019             NaN
# 231       Bahamas  2000             NaN
# 232       Bahamas  2001             NaN
# ...           ...   ...             ...
# 3601        Yemen  2015             NaN
# 3602        Yemen  2016             NaN
# 3603        Yemen  2017             NaN
# 3604        Yemen  2018             NaN
# 3605        Yemen  2019             NaN
#
# [265 rows x 3 columns]

# %% [markdown]
# Los voy a rellenar con valores del año anterior

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2['Entity'] == 'Afghanistan'][['Entity', 'Year', 'gdp_per_capita']]
# Out:
#          Entity  Year  gdp_per_capita
# 0   Afghanistan  2000             NaN
# 1   Afghanistan  2001             NaN
# 2   Afghanistan  2002      179.426579
# 3   Afghanistan  2003      190.683814
# 4   Afghanistan  2004      211.382074
# 5   Afghanistan  2005      242.031313
# 6   Afghanistan  2006      263.733602
# 7   Afghanistan  2007      359.693158
# 8   Afghanistan  2008      364.663542
# 9   Afghanistan  2009      437.268740
# 10  Afghanistan  2010      543.306526
# 11  Afghanistan  2011      591.190030
# 12  Afghanistan  2012      638.845852
# 13  Afghanistan  2013      624.315454
# 14  Afghanistan  2014      614.223342
# 15  Afghanistan  2015      556.007221
# 16  Afghanistan  2016      512.012778
# 17  Afghanistan  2017      516.679862
# 18  Afghanistan  2018      485.668419
# 19  Afghanistan  2019      494.179350

# %%
#PRIMERA LIMPIEZA
# Asegurarse de que está ordenado por país y año
#df_energy_2 = df_energy_2.sort_values(by=['Entity', 'Year'])

# Aplicar solo backward fill (rellenar con el valor del año posterior)
df_energy_2['gdp_per_capita'] = (
    df_energy_2.groupby('Entity', group_keys=False)['gdp_per_capita']
    .apply(lambda x: x.bfill())
)

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2['Entity'] == 'Afghanistan'][['Entity', 'Year', 'gdp_per_capita']]
# Out:
#          Entity  Year  gdp_per_capita
# 0   Afghanistan  2000      179.426579
# 1   Afghanistan  2001      179.426579
# 2   Afghanistan  2002      179.426579
# 3   Afghanistan  2003      190.683814
# 4   Afghanistan  2004      211.382074
# 5   Afghanistan  2005      242.031313
# 6   Afghanistan  2006      263.733602
# 7   Afghanistan  2007      359.693158
# 8   Afghanistan  2008      364.663542
# 9   Afghanistan  2009      437.268740
# 10  Afghanistan  2010      543.306526
# 11  Afghanistan  2011      591.190030
# 12  Afghanistan  2012      638.845852
# 13  Afghanistan  2013      624.315454
# 14  Afghanistan  2014      614.223342
# 15  Afghanistan  2015      556.007221
# 16  Afghanistan  2016      512.012778
# 17  Afghanistan  2017      516.679862
# 18  Afghanistan  2018      485.668419
# 19  Afghanistan  2019      494.179350

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["gdp_per_capita"].isna()]["Entity"].drop_duplicates()
# Out:
# 166                                Aruba
# 231                              Bahamas
# 777                                Congo
# 882                              Czechia
# 1008                               Egypt
# 1083                             Eritrea
# 1240                              Gambia
# 1807                          Kyrgyzstan
# 2766               Saint Kitts and Nevis
# 2787                         Saint Lucia
# 2808    Saint Vincent and the Grenadines
# 2990                            Slovakia
# 3098                         South Sudan
# 3586                               Yemen
# Name: Entity, dtype: object

# %%
#PRIMERA LIMPIEZA
print(df_energy_2['gdp_per_capita'].isna().sum())
# Out:
# 233

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2['Entity'] == 'Aruba'][['Entity', 'Year', 'gdp_per_capita']]
# Out:
#     Entity  Year  gdp_per_capita
# 147  Aruba  2000     20617.75047
# 148  Aruba  2001     20670.36701
# 149  Aruba  2002     20436.88713
# 150  Aruba  2003     20833.97636
# 151  Aruba  2004     22568.37499
# 152  Aruba  2005     23300.73836
# 153  Aruba  2006     24046.22638
# 154  Aruba  2007     25834.11178
# 155  Aruba  2008     27083.63486
# 156  Aruba  2009     24631.18205
# 157  Aruba  2010     23513.52770
# 158  Aruba  2011     24985.01392
# 159  Aruba  2012     24712.49326
# 160  Aruba  2013     26441.61994
# 161  Aruba  2014     26893.01151
# 162  Aruba  2015     28396.90842
# 163  Aruba  2016     28452.17061
# 164  Aruba  2017     29350.80502
# 165  Aruba  2018     30253.27936
# 166  Aruba  2019             NaN

# %%
#PRIMERA LIMPIEZA
#ahora con el valor anterior
# Asegurar que los datos estén ordenados por país y año
#df_energy_2 = df_energy_2.sort_values(by=['Entity', 'Year'])

# Aplicar solo forward fill (relleno con el valor anterior)
df_energy_2['gdp_per_capita'] = (
    df_energy_2.groupby('Entity', group_keys=False)['gdp_per_capita']
    .apply(lambda x: x.ffill())
)

# %%
#PRIMERA LIMPIEZA
print(df_energy_2['gdp_per_capita'].isna().sum())
# Out:
# 220

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2["gdp_per_capita"].isna()]["Entity"].drop_duplicates()
# Out:
# 231                              Bahamas
# 777                                Congo
# 882                              Czechia
# 1008                               Egypt
# 1240                              Gambia
# 1807                          Kyrgyzstan
# 2766               Saint Kitts and Nevis
# 2787                         Saint Lucia
# 2808    Saint Vincent and the Grenadines
# 2990                            Slovakia
# 3586                               Yemen
# Name: Entity, dtype: object

# %%
#PRIMERA LIMPIEZA
df_energy_2[df_energy_2['Entity'] == 'Bahamas'][['Entity', 'Year', 'gdp_per_capita']]
# Out:
#       Entity  Year  gdp_per_capita
# 231  Bahamas  2000             NaN
# 232  Bahamas  2001             NaN
# 233  Bahamas  2002             NaN
# 234  Bahamas  2003             NaN
# 235  Bahamas  2004             NaN
# 236  Bahamas  2005             NaN
# 237  Bahamas  2006             NaN
# 238  Bahamas  2007             NaN
# 239  Bahamas  2008             NaN
# 240  Bahamas  2009             NaN
# 241  Bahamas  2010             NaN
# 242  Bahamas  2011             NaN
# 243  Bahamas  2012             NaN
# 244  Bahamas  2013             NaN
# 245  Bahamas  2014             NaN
# 246  Bahamas  2015             NaN
# 247  Bahamas  2016             NaN
# 248  Bahamas  2017             NaN
# 249  Bahamas  2018             NaN
# 250  Bahamas  2019             NaN

# %% [markdown]
# El resto de paises tiene este dato a NaN. Demomento voy a crear df:energy_3

# %% [markdown]
# ### HIPOTESIS 1
# Los países con mayor intensidad energética tienen un menor grado de eficiencia económica.
# Relación entre “Energy intensity level of primary energy” y “gdp_per_capita”.

# %%
df_limpio=pd.read_csv ("primera_limpieza.csv")

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3453 entries, 0 to 3452
# Data columns (total 21 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Entity                                                               3453 non-null   object
#  1   Year                                                                 3453 non-null   int64
#  2   Access to electricity (perc of population)                           3453 non-null   float64
#  3   Access to clean fuels for cooking                                    3293 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita                 2567 non-null   float64
#  5   Financial flows to developing countries (US dolar)                   3453 non-null   float64
# ...

# %%
#Elimino los paises que tienen Nulo gpd per capita
#df_energy_3 = df_energy_2.dropna(subset=['gdp_per_capita'])
df_energy_3 = df_limpio.dropna(subset=['gdp_per_capita'])

# %%
#df_energy_2.isnull().sum()
df_limpio.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    886
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %%
df_energy_3.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    846
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ya está a cero gpd per capita
#
# Ahora miro la otra variable

# %%
df_energy_3[df_energy_3["Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)"].isna()]["Entity"].drop_duplicates()
# Out:
# 1036          Eritrea
# 2233    New Caledonia
# 2949      South Sudan
# Name: Entity, dtype: object

# %%
#Voy mirando estos 3 paises
df_energy_3[df_energy_3['Entity'] == 'South Sudan'][['Entity', 'Year', 'Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)']]
# Out:
#            Entity  Year  \
# 2946  South Sudan  2013
# 2947  South Sudan  2014
# 2948  South Sudan  2015
# 2949  South Sudan  2016
# 2950  South Sudan  2017
# 2951  South Sudan  2018
# 2952  South Sudan  2019
#
#       Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)
# 2946                                           1.277480
# 2947                                           1.298349
# 2948                                           1.086098
# 2949                                                NaN
# 2950                                                NaN
# 2951                                                NaN
# 2952                                                NaN

# %%
df_energy_3[df_energy_3['Entity'] == 'Eritrea'][['Entity', 'Year', 'Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)']]
#Lo relleno con la media
# Out:
#        Entity  Year  \
# 1020  Eritrea  2000
# 1021  Eritrea  2001
# 1022  Eritrea  2002
# 1023  Eritrea  2003
# 1024  Eritrea  2004
# 1025  Eritrea  2005
# 1026  Eritrea  2006
# 1027  Eritrea  2007
# 1028  Eritrea  2008
# 1029  Eritrea  2009
# 1030  Eritrea  2010
# 1031  Eritrea  2011
# 1032  Eritrea  2012
# 1033  Eritrea  2013
# 1034  Eritrea  2014
# 1035  Eritrea  2015
# 1036  Eritrea  2016
# 1037  Eritrea  2017
# 1038  Eritrea  2018
# 1039  Eritrea  2019
#
#       Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)
# 1020                                           5.202373
# 1021                                           5.012198
# 1022                                           4.909889
# 1023                                           5.401414
# 1024                                           4.939409
# 1025                                           4.934521
# 1026                                           4.539425
# ...

# %% [markdown]
# Tengo que quitar new caledonia que esta todo a Nan y ver que hago con Eritrea que tiene 2 y South Sudan 4

# %%
df_energy_4 = df_energy_3[df_energy_3['Entity'] != 'New Caledonia']

# %%
df_energy_4[df_energy_4["Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)"].isna()]["Entity"].drop_duplicates()
# Out:
# 1036        Eritrea
# 2949    South Sudan
# Name: Entity, dtype: object

# %%
#voy a rellenar lo de estos dos paises con la media de tos los años 
df_energy_4['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)'] = df_energy_4.groupby('Entity')['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)'].transform(lambda x: x.fillna(x.mean()))
# Out:
# C:\Users\leire\AppData\Local\Temp\ipykernel_13404\539795173.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_energy_4['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)'] = df_energy_4.groupby('Entity')['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)'].transform(lambda x: x.fillna(x.mean()))

# %%
df_energy_4[df_energy_4["Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)"].isna()]["Entity"].drop_duplicates()
# Out:
# Series([], Name: Entity, dtype: object)

# %%
df_energy_4.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       140
# Renewable-electricity-generating-capacity-per-capita                    846
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ya puedo mostrar la primera hipotesis

# %% [markdown]
# Los países con mayor intensidad energética tienen un menor grado de eficiencia económica.
# Relación entre “Energy intensity level of primary energy” y “gdp_per_capita”.

# %%
df_energy_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3213 entries, 0 to 3647
# Data columns (total 22 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Entity                                                               3213 non-null   object
#  1   Year                                                                 3213 non-null   int64
#  2   Access to electricity (perc of population)                           3213 non-null   float64
#  3   Access to clean fuels for cooking                                    3073 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita                 2367 non-null   float64
#  5   Financial flows to developing countries (US dolar)                   3213 non-null   float64
# ...

# %% [markdown]
# Grafico HIPOTESIS 1

# %%
sns.lmplot(x="gdp_per_capita", y="Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)", data=df_energy_3,fit_reg=False)
#plt.xlim(0, 10000)
plt.show()

# %% [markdown]
# Para hipotesis 2
#
# tengo que poner a cero la columna Value_C02

# %%
df_energy_4[df_energy_4["Value_co2_emissions_kt_by_country"].isna()]["Entity"].drop_duplicates()
# Out:
# 164              Aruba
# 416            Bermuda
# 647     Cayman Islands
# 2682       Puerto Rico
# 3355            Turkey
# Name: Entity, dtype: object

# %%
df_energy_4[df_energy_4['Entity'] == 'Turkey'][['Entity', 'Year', 'Value_co2_emissions_kt_by_country']]
# Out:
#       Entity  Year  Value_co2_emissions_kt_by_country
# 3355  Turkey  2000                                NaN
# 3356  Turkey  2001                                NaN
# 3357  Turkey  2002                                NaN
# 3358  Turkey  2003                                NaN
# 3359  Turkey  2004                                NaN
# 3360  Turkey  2005                                NaN
# 3361  Turkey  2006                                NaN
# 3362  Turkey  2007                                NaN
# 3363  Turkey  2008                                NaN
# 3364  Turkey  2009                                NaN
# 3365  Turkey  2010                                NaN
# 3366  Turkey  2011                                NaN
# 3367  Turkey  2012                                NaN
# 3368  Turkey  2013                                NaN
# 3369  Turkey  2014                                NaN
# 3370  Turkey  2015                                NaN
# ...

# %%
df_energy_4[df_energy_4['Entity'] == 'Bermuda'][['Entity', 'Year', 'Value_co2_emissions_kt_by_country']]
# Out:
#       Entity  Year  Value_co2_emissions_kt_by_country
# 399  Bermuda  2000                            517.047
# 400  Bermuda  2001                            528.048
# 401  Bermuda  2002                            557.384
# 402  Bermuda  2003                            561.051
# 403  Bermuda  2004                            583.053
# 404  Bermuda  2005                            583.053
# 405  Bermuda  2006                            652.726
# 406  Bermuda  2007                            729.733
# 407  Bermuda  2008                            649.059
# 408  Bermuda  2009                            476.710
# 409  Bermuda  2010                            608.722
# 410  Bermuda  2011                            443.707
# 411  Bermuda  2012                            366.700
# 412  Bermuda  2013                            509.713
# 413  Bermuda  2014                            649.059
# 414  Bermuda  2015                            557.384
# ...

# %% [markdown]
# Turquia y Puerto Rico Estan todo a nulo, estos paises los quito.
#
# El resto hago igual que el valor anterior

# %%
df_energy_4['Value_co2_emissions_kt_by_country'] = df_energy_4.groupby('Entity')['Value_co2_emissions_kt_by_country'].transform(lambda x: x.fillna(x.mean()))
# Out:
# C:\Users\leire\AppData\Local\Temp\ipykernel_13404\2365452518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_energy_4['Value_co2_emissions_kt_by_country'] = df_energy_4.groupby('Entity')['Value_co2_emissions_kt_by_country'].transform(lambda x: x.fillna(x.mean()))

# %%
df_energy_4[df_energy_4["Value_co2_emissions_kt_by_country"].isna()]["Entity"].drop_duplicates()
# Out:
# 2682    Puerto Rico
# 3355         Turkey
# Name: Entity, dtype: object

# %%
df_energy_4 = df_energy_4.dropna(subset=['Value_co2_emissions_kt_by_country'])

# %%
df_energy_4[df_energy_4["Value_co2_emissions_kt_by_country"].isna()]["Entity"].drop_duplicates()
# Out:
# Series([], Name: Entity, dtype: object)

# %%
df_energy_4.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       120
# Renewable-electricity-generating-capacity-per-capita                    846
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# *** HIPOTESIS 3- El acceso a combustibles limpios para cocinar está positivamente correlacionado con el nivel de desarrollo económico.
# Relación entre “Access to clean fuels for cooking” y “gdp_per_capita”.

# %%
df_energy_3[df_energy_3["Access to clean fuels for cooking"].isna()]["Entity"].drop_duplicates()
# Out:
# 147              Aruba
# 399            Bermuda
# 504           Bulgaria
# 630     Cayman Islands
# 1849           Lebanon
# 1912             Libya
# 2346     New Caledonia
# 2682       Puerto Rico
# Name: Entity, dtype: object

# %%
df_energy_3[df_energy_3['Entity'] == 'Puerto Rico'][['Entity', 'Year', 'Access to clean fuels for cooking']]
# Out:
#            Entity  Year  Access to clean fuels for cooking
# 2682  Puerto Rico  2000                                NaN
# 2683  Puerto Rico  2001                                NaN
# 2684  Puerto Rico  2002                                NaN
# 2685  Puerto Rico  2003                                NaN
# 2686  Puerto Rico  2004                                NaN
# 2687  Puerto Rico  2005                                NaN
# 2688  Puerto Rico  2006                                NaN
# 2689  Puerto Rico  2007                                NaN
# 2690  Puerto Rico  2008                                NaN
# 2691  Puerto Rico  2009                                NaN
# 2692  Puerto Rico  2010                                NaN
# 2693  Puerto Rico  2011                                NaN
# 2694  Puerto Rico  2012                                NaN
# 2695  Puerto Rico  2013                                NaN
# 2696  Puerto Rico  2014                                NaN
# ...

# %% [markdown]
# Son todos cero, elimimo etos paises porque no se si es cero o no hay datos

# %%
df_energy_5 = df_energy_3.dropna(subset=['Access to clean fuels for cooking'])

# %%
df_energy_5.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                         0
# Renewable-electricity-generating-capacity-per-capita                    806
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                 0
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ### 4- Los países con mayor participación de energía renovable en el consumo final tienen una menor intensidad energética.
# Relación entre “Renewable energy share in the total final energy consumption” y “Energy intensity level of primary energy”.

# %%
df_energy_3[df_energy_3["Renewable energy share in the total final energy consumption (perc)"].isna()]["Entity"].drop_duplicates()
# Out:
# 21    Albania
# Name: Entity, dtype: object

# %%
df_energy_3[df_energy_3['Entity'] == 'Albania'][['Entity', 'Year', 'Renewable energy share in the total final energy consumption (perc)']]
# Out:
#      Entity  Year  \
# 21  Albania  2000
# 22  Albania  2001
# 23  Albania  2002
# 24  Albania  2003
# 25  Albania  2004
# 26  Albania  2005
# 27  Albania  2006
# 28  Albania  2007
# 29  Albania  2008
# 30  Albania  2009
# 31  Albania  2010
# 32  Albania  2011
# 33  Albania  2012
# 34  Albania  2013
# 35  Albania  2014
# 36  Albania  2015
# 37  Albania  2016
# 38  Albania  2017
# 39  Albania  2018
# 40  Albania  2019
#
#     Renewable energy share in the total final energy consumption (perc)
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# ...

# %% [markdown]
# Voy a Eliminar las lineas de Albania

# %%
df_energy_6 = df_energy_3.dropna(subset=['Renewable energy share in the total final energy consumption (perc)'])

# %%
df_energy_6.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    826
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)       0
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %%
df_energy_6[df_energy_6["Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)"].isna()]["Entity"].drop_duplicates()
# Out:
# 1087          Eritrea
# 2346    New Caledonia
# 3098      South Sudan
# Name: Entity, dtype: object

# %%
df_energy_6[df_energy_6['Entity'] == 'Eritrea'][['Entity', 'Year', 'Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)']]
# Out:
#        Entity  Year  \
# 1071  Eritrea  2000
# 1072  Eritrea  2001
# 1073  Eritrea  2002
# 1074  Eritrea  2003
# 1075  Eritrea  2004
# 1076  Eritrea  2005
# 1077  Eritrea  2006
# 1078  Eritrea  2007
# 1079  Eritrea  2008
# 1080  Eritrea  2009
# 1081  Eritrea  2010
# 1082  Eritrea  2011
# 1083  Eritrea  2012
# 1084  Eritrea  2013
# 1085  Eritrea  2014
# 1086  Eritrea  2015
# 1087  Eritrea  2016
# 1088  Eritrea  2017
# 1089  Eritrea  2018
# 1090  Eritrea  2019
#
#       Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)
# 1071                                           5.202373
# 1072                                           5.012198
# 1073                                           4.909889
# 1074                                           5.401414
# 1075                                           4.939409
# 1076                                           4.934521
# 1077                                           4.539425
# ...

# %% [markdown]
# Elimino las de NEw Caledoni a y las otras 2 pongo los valores anteriores

# %%
# Aplicar solo forward fill (relleno con el valor anterior)
df_energy_6['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)'] = (
    df_energy_6.groupby('Entity', group_keys=False)['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)']
    .apply(lambda x: x.ffill())
)
# Out:
# C:\Users\leire\AppData\Local\Temp\ipykernel_15188\418012047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_energy_6['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)'] = (

# %%
df_energy_6[df_energy_6["Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)"].isna()]["Entity"].drop_duplicates()
# Out:
# 2346    New Caledonia
# Name: Entity, dtype: object

# %%
df_energy_6 = df_energy_3.dropna(subset=['Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)'])

# %%
df_energy_6[df_energy_6["Energy intensity level of primary energy (MJ/dolar2017 PPP GDP)"].isna()]["Entity"].drop_duplicates()
# Out:
# Series([], Name: Entity, dtype: object)

# %%
df_energy_6.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       140
# Renewable-electricity-generating-capacity-per-capita                    846
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %% [markdown]
# ### 5- Los paises más ricos son los que compran mas creditos de carbono. Y los mas pobres los que los venden.
# Financial flows to developing countries (US dolar) --> es de los paises que reciben el dinero, no de los que lo dan.
#
# gdp_per_capita

# %%
df_energy_3
# Out:
#            Entity  Year  Access to electricity (perc of population)  \
# 0     Afghanistan  2000                                    1.613591
# 1     Afghanistan  2001                                    4.074574
# 2     Afghanistan  2002                                    9.409158
# 3     Afghanistan  2003                                   14.738506
# 4     Afghanistan  2004                                   20.064968
# ...           ...   ...                                         ...
# 3643     Zimbabwe  2015                                   33.700000
# 3644     Zimbabwe  2016                                   42.561730
# 3645     Zimbabwe  2017                                   44.178635
# 3646     Zimbabwe  2018                                   45.572647
# 3647     Zimbabwe  2019                                   46.781475
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# ...

# %%
df_energy_3.isnull().sum()#tengo las dos variables limpias
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       160
# Renewable-electricity-generating-capacity-per-capita                    846
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %%
sns.lmplot(x="gdp_per_capita", y="Financial flows to developing countries (US dolar)", data=df_energy_3,fit_reg=False)
#plt.xlim(0, 10000)
plt.show()

# %%
paises_gdp_bajo = df_energy_3[df_energy_3["gdp_per_capita"] < 200]["Entity"].drop_duplicates()

print(paises_gdp_bajo)
# Out:
# 0        Afghanistan
# 546          Burundi
# 672             Chad
# 1134        Ethiopia
# 1996          Malawi
# 2241         Myanmar
# 2409           Niger
# 2948    Sierra Leone
# 3229      Tajikistan
# Name: Entity, dtype: object

# %%
#zoom
sns.lmplot(x="gdp_per_capita", y="Financial flows to developing countries (US dolar)", data=df_energy_3,fit_reg=False)
plt.xlim(0, 10000)
plt.show()

# %%
top_10 = df_energy_3.sort_values(by="Financial flows to developing countries (US dolar)", ascending=False).head(20)
top_10[["Entity", "Financial flows to developing countries (US dolar)"]]
# Out:
#          Entity  Financial flows to developing countries (US dolar)
# 2447    Nigeria                                       5.202310e+09
# 1143   Ethiopia                                       4.284370e+09
# 2531   Pakistan                                       3.386850e+09
# 997     Ecuador                                       2.811680e+09
# 119   Argentina                                       2.472850e+09
# 1550      India                                       2.112780e+09
# 1545      India                                       1.950940e+09
# 3622     Zambia                                       1.791180e+09
# 1552      India                                       1.764130e+09
# 3431     Uganda                                       1.470000e+09
# 751    Colombia                                       1.454760e+09
# 2213    Morocco                                       1.433570e+09
# 2526   Pakistan                                       1.386720e+09
# ...

# %%
df_filtrado = df_energy_3[(df_energy_3["Year"] == 2019)]
sns.lmplot(x="gdp_per_capita", y="Financial flows to developing countries (US dolar)", data=df_filtrado,fit_reg=False)
#plt.xlim(0, 10000)
plt.show()

# %%
sns.lmplot(
    x="gdp_per_capita",
    y="Financial flows to developing countries (US dolar)",
    data=df_energy_3,
    hue="Year",      # Colores por año
    palette="viridis", 
    fit_reg=False,
    height=6,
    aspect=1.5
)

plt.title("Financial Flows vs GDP per Capita (Todos los años)")
plt.show()

# %% [markdown]
# Grafico cada pais cuanta pasta recibe

# %%
# Agrupar y sumar los flujos financieros por país
flows_por_pais = df_energy_3.groupby("Entity")["Financial flows to developing countries (US dolar)"].sum()

# Eliminar NaN o países con valor 0
#flows_por_pais = flows_por_pais.dropna()
#flows_por_pais = flows_por_pais[flows_por_pais > 0]

# Ordenar por valor
flows_por_pais = flows_por_pais.sort_values(ascending=False)

# Opción: mostrar solo los 10 países que más reciben
flows_top10 = flows_por_pais.head(20)

# Gráfico de tarta
plt.figure(figsize=(8, 8))
plt.pie(flows_top10, labels=flows_top10.index, autopct='%1.1f%%', startangle=140)
plt.title("Top 10 países por dinero recibido (Financial flows)")
plt.axis('equal')  # Para que el gráfico sea un círculo
plt.tight_layout()
plt.show()

# %%
# Agrupar y sumar los flujos financieros por país
flows_por_pais = df_energy_3.groupby("Entity")["gdp_per_capita"].sum()

# Eliminar NaN o países con valor 0
#flows_por_pais = flows_por_pais.dropna()
#flows_por_pais = flows_por_pais[flows_por_pais > 0]

# Ordenar por valor
flows_por_pais = flows_por_pais.sort_values(ascending=True)

# Opción: mostrar solo los 10 países que más reciben
flows_top10 = flows_por_pais.head(20)

# Gráfico de tarta
plt.figure(figsize=(8, 8))
plt.pie(flows_top10, labels=flows_top10.index, autopct='%1.1f%%', startangle=140)
plt.title("Top 10 países mas pobre_menor PIB")
plt.axis('equal')  # Para que el gráfico sea un círculo
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6- Los paises ricos emiten más CO2 que lo compensan con la copra de creditos de carbono.
#
# Value_co2_emissions_kt_by_country
#
# Financial flows to developing countries (US dolar)

# %%
df_energy_4.isnull().sum()
# Out:
# Entity                                                                    0
# Year                                                                      0
# Access to electricity (perc of population)                                0
# Access to clean fuels for cooking                                       120
# Renewable-electricity-generating-capacity-per-capita                    846
# Financial flows to developing countries (US dolar)                        0
# Renewable energy share in the total final energy consumption (perc)      20
# Electricity from fossil fuels (TWh)                                       0
# Electricity from nuclear (TWh)                                            0
# Electricity from renewables (TWh)                                         0
# Low-carbon electricity (perc electricity)                                20
# Primary energy consumption per capita (kWh/person)                        0
# ...

# %%
#sns.lmplot(x="Value_co2_emissions_kt_by_country", y="Financial flows to developing countries (US dolar)", data=df_energy_4,fit_reg=False)
#sns.lmplot(x="Financial flows to developing countries (US dolar)", y="Value_co2_emissions_kt_by_country", data=df_energy_4,fit_reg=False)
sns.lmplot(x="Value_co2_emissions_kt_by_country", y="Financial flows to developing countries (US dolar)", data=df_energy_4,fit_reg=False)
#plt.xlim(0, 20000)
plt.show()

# %%
df_mayor_10000 = df_energy_3[df_energy_3["Financial flows to developing countries (US dolar)"] > 100000]

df_mayor_10000 = df_mayor_10000[["Entity", "Year", "gdp_per_capita", "Financial flows to developing countries (US dolar)"]]
df_mayor_10000
# Out:
#            Entity  Year  gdp_per_capita  \
# 1     Afghanistan  2001      179.426579
# 2     Afghanistan  2002      179.426579
# 3     Afghanistan  2003      190.683814
# 5     Afghanistan  2005      242.031313
# 6     Afghanistan  2006      263.733602
# ...           ...   ...             ...
# 3639     Zimbabwe  2011     1093.653409
# 3641     Zimbabwe  2013     1429.998461
# 3642     Zimbabwe  2014     1434.896277
# 3645     Zimbabwe  2017     1235.189032
# 3647     Zimbabwe  2019     1316.740657
#
#       Financial flows to developing countries (US dolar)
# 1                                              130000.0
# 2                                             3950000.0
# 3                                            25970000.0
# 5                                             9830000.0
# 6                                            10620000.0
# ...                                                 ...
# 3639                                          1080000.0
# ...
